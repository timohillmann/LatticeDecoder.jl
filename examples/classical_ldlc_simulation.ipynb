# %% [markdown]
# In this example, we will demonstrate how to create and decode a classical Low-Densit Lattice Code (LDLC).

# %%
using LatticeDecoder

# %%
n = 7
d = 3
H = LatticeDecoder.classical_ldlc(n, d)
# Out:
# UndefVarError: `classical_ldlc` not defined
#
#
#
# Stacktrace:
#
#  [1] getproperty(x::Module, f::Symbol)
#
#    @ Base ./Base.jl:31
#
#  [2] top-level scope
#
#    @ ~/Documents/GitHub/LatticeDecoder.jl/examples/classical_ldlc_simulation.ipynb:3
